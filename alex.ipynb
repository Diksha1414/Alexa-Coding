# %%
import pyttsx3 #pip install pyttsx3
import speech_recognition as sr #pip install speechRecognition
import pyaudio
import datetime
import wikipedia #pip install wikipedia
import webbrowser
import os
import smtplib

print("Initializing Galaxy")
MASTER = "Diksha"

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
#Speak function will speak/Pronounce the string which is passed to it
def speak(audio):
    engine.say(audio)
    engine.runAndWait()

#This funtion will wish you as per the current time
def wishMe():
    hour = int(datetime.datetime.now().hour)
    print(hour)

    if hour>=0 and hour <12:
        speak("good morning" + MASTER)

    elif hour>=12 and hour<18:
        speak("good afternoon" + MASTER)

    else:
        speak("good evening" + MASTER)

    speak("hello! I am virtual assistant ALEX")

#This function will take command from the microphone
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try :
        print("Recognizing...")
        query = r.recognize_google(audio, language = 'en-in')
        print(f"user said: {query}\n")

    except Exception as e:
        speak("Say that again please...")
        print("Say that again please...")
        return "None"
    return query

#main program starting
def main():
    speak("Initializing Galaxy...")
    wishMe()

    #Logic for executing tasks as per the query

    while True:
        query = takeCommand().lower()
        if 'hi galaxy' in query or 'hello galaxy' in query:
            speak('Hello there...!!! How are you?')

        elif 'good' in query or 'i am fine' in query:
            speak("that's great, happy to hear that")

        elif 'how are you' in query:
            speak("i am fine, let me know if you need some help.")

        elif 'ok' in query:
            speak("okay")

        elif 'who are you' in query:
            speak("i am a virtual assistant. Can do certain things")

        elif 'quit' in query or 'exit' in query or 'quit galaxy' in query or 'exit galaxy' in query or 'bye' in query or 'bye galaxy' in query:
            speak("Thank you guys for your time .  !!!! Have a nice day. ...")

        elif 'open youtube' in query.lower():
            webbrowser.open('youtube.com')
            url = "youtube.com"
            chrome_path = 'C:\Program Files\Google\Chrome\Application\chrome.exe %s'
            webbrowser.get(chrome_path).open(url)

        elif 'open google' in query.lower():
            webbrowser.open('google.com')
            url = "google.com"
            chrome_path = 'C:\Program Files\Google\Chrome\Application\chrome.exe %s'
            webbrowser.get(chrome_path).open(url)

        elif 'the time' in query.lower():
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"{MASTER} the time is {strTime}")
if __name__ == "__main__":
    main()
    takeCommand()
# Out:
# Initializing Galaxy
# 22
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 99
#      97             speak(f"{MASTER} the time is {strTime}")
#      98 if __name__ == "__main__":
# ---> 99     main()
#     100     takeCommand()
#
# Cell In[1], line 64, in main()
#      61 #Logic for executing tasks as per the query
#      63 while True:
# ---> 64     query = takeCommand().lower()
#      65     if 'hi galaxy' in query or 'hello galaxy' in query:
#      66         speak('Hello there...!!! How are you?')
#
# Cell In[1], line 43, in takeCommand()
#      41     print("Listening...")
#      42     r.pause_threshold = 1
# ---> 43     audio = r.listen(source)
#      45 try :
#      46     print("Recognizing...")
#
# ...
